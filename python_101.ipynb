# %% [markdown]
# <a href="https://colab.research.google.com/github/aayshakhanam857-alt/Rebounce-Applied-AI-and-Analytics-Codes/blob/main/python_101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("MP1_starting")
# Out:
# MP1_starting
